# %% [markdown]
# # Probabilities
#
# For a given batch size, what is the probability that the next generated number is greater than `k`?

# %%
import pandas as pd
from math import comb

def calculate_combinatorial_probabilities(min_num: int, max_num: int) -> pd.DataFrame:
    data = []
    total_numbers = max_num - min_num + 1

    for k in range(min_num, max_num + 1):
        row = {}
        numbers_greater_than_k = max_num - k
        for batch_size in range(0, total_numbers + 1):
            favorable_combinations = comb(numbers_greater_than_k, batch_size)
            total_combinations = comb(total_numbers, batch_size)
            probability = favorable_combinations / total_combinations
            row[f'Batch Size {batch_size}'] = probability
        data.append(row)

    # Create a DataFrame
    df = pd.DataFrame(data, index=[f'k = {k}' for k in range(min_num, max_num + 1)])
    return df

# Parameters
min_num = 1
max_num = 10

# Generate the table
probability_table = calculate_combinatorial_probabilities(min_num, max_num)

# Display the table
probability_table.style.background_gradient(cmap='viridis', vmin=0, vmax=1)
# Out:
# Probability of k being
# <style type="text/css">
# #T_74382_row0_col0, #T_74382_row1_col0, #T_74382_row2_col0, #T_74382_row3_col0, #T_74382_row4_col0, #T_74382_row5_col0, #T_74382_row6_col0, #T_74382_row7_col0, #T_74382_row8_col0, #T_74382_row9_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_74382_row0_col1 {
#   background-color: #bddf26;
#   color: #000000;
# }
# #T_74382_row0_col2, #T_74382_row1_col1 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_74382_row0_col3, #T_74382_row2_col1 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_74382_row0_col4, #T_74382_row3_col1 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_74382_row0_col5, #T_74382_row4_col1 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_74382_row0_col6, #T_74382_row5_col1 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_74382_row0_col7, #T_74382_row6_col1 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_74382_row0_col8, #T_74382_row7_col1 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_74382_row0_col9, #T_74382_row8_col1 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_74382_row0_col10, #T_74382_row1_col9, #T_74382_row1_col10, #T_74382_row2_col8, #T_74382_row2_col9, #T_74382_row2_col10, #T_74382_row3_col7, #T_74382_row3_col8, #T_74382_row3_col9, #T_74382_row3_col10, #T_74382_row4_col6, #T_74382_row4_col7, #T_74382_row4_col8, #T_74382_row4_col9, #T_74382_row4_col10, #T_74382_row5_col5, #T_74382_row5_col6, #T_74382_row5_col7, #T_74382_row5_col8, #T_74382_row5_col9, #T_74382_row5_col10, #T_74382_row6_col4, #T_74382_row6_col5, #T_74382_row6_col6, #T_74382_row6_col7, #T_74382_row6_col8, #T_74382_row6_col9, #T_74382_row6_col10, #T_74382_row7_col3, #T_74382_row7_col4, #T_74382_row7_col5, #T_74382_row7_col6, #T_74382_row7_col7, #T_74382_row7_col8, #T_74382_row7_col9, #T_74382_row7_col10, #T_74382_row8_col2, #T_74382_row8_col3, #T_74382_row8_col4, #T_74382_row8_col5, #T_74382_row8_col6, #T_74382_row8_col7, #T_74382_row8_col8, #T_74382_row8_col9, #T_74382_row8_col10, #T_74382_row9_col1, #T_74382_row9_col2, #T_74382_row9_col3, #T_74382_row9_col4, #T_74382_row9_col5, #T_74382_row9_col6, #T_74382_row9_col7, #T_74382_row9_col8, #T_74382_row9_col9, #T_74382_row9_col10 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_74382_row1_col2 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_74382_row1_col3, #T_74382_row2_col2 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_74382_row1_col4, #T_74382_row3_col2 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_74382_row1_col5, #T_74382_row4_col2 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_74382_row1_col6, #T_74382_row5_col2 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_74382_row1_col7, #T_74382_row6_col2 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_74382_row1_col8, #T_74382_row7_col2 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_74382_row2_col3 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_74382_row2_col4, #T_74382_row3_col3 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_74382_row2_col5, #T_74382_row4_col3 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_74382_row2_col6, #T_74382_row5_col3 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_74382_row2_col7, #T_74382_row6_col3 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_74382_row3_col4 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_74382_row3_col5, #T_74382_row4_col4 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_74382_row3_col6, #T_74382_row4_col5, #T_74382_row5_col4 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_74382">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74382_level0_col0" class="col_heading level0 col0" >Batch Size 0</th>
#       <th id="T_74382_level0_col1" class="col_heading level0 col1" >Batch Size 1</th>
#       <th id="T_74382_level0_col2" class="col_heading level0 col2" >Batch Size 2</th>
#       <th id="T_74382_level0_col3" class="col_heading level0 col3" >Batch Size 3</th>
#       <th id="T_74382_level0_col4" class="col_heading level0 col4" >Batch Size 4</th>
#       <th id="T_74382_level0_col5" class="col_heading level0 col5" >Batch Size 5</th>
#       <th id="T_74382_level0_col6" class="col_heading level0 col6" >Batch Size 6</th>
#       <th id="T_74382_level0_col7" class="col_heading level0 col7" >Batch Size 7</th>
#       <th id="T_74382_level0_col8" class="col_heading level0 col8" >Batch Size 8</th>
#       <th id="T_74382_level0_col9" class="col_heading level0 col9" >Batch Size 9</th>
#       <th id="T_74382_level0_col10" class="col_heading level0 col10" >Batch Size 10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74382_level0_row0" class="row_heading level0 row0" >k = 1</th>
#       <td id="T_74382_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_74382_row0_col1" class="data row0 col1" >0.900000</td>
#       <td id="T_74382_row0_col2" class="data row0 col2" >0.800000</td>
#       <td id="T_74382_row0_col3" class="data row0 col3" >0.700000</td>
#       <td id="T_74382_row0_col4" class="data row0 col4" >0.600000</td>
#       <td id="T_74382_row0_col5" class="data row0 col5" >0.500000</td>
#       <td id="T_74382_row0_col6" class="data row0 col6" >0.400000</td>
#       <td id="T_74382_row0_col7" class="data row0 col7" >0.300000</td>
#       <td id="T_74382_row0_col8" class="data row0 col8" >0.200000</td>
#       <td id="T_74382_row0_col9" class="data row0 col9" >0.100000</td>
#       <td id="T_74382_row0_col10" class="data row0 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_74382_level0_row1" class="row_heading level0 row1" >k = 2</th>
#       <td id="T_74382_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_74382_row1_col1" class="data row1 col1" >0.800000</td>
#       <td id="T_74382_row1_col2" class="data row1 col2" >0.622222</td>
#       <td id="T_74382_row1_col3" class="data row1 col3" >0.466667</td>
#       <td id="T_74382_row1_col4" class="data row1 col4" >0.333333</td>
#       <td id="T_74382_row1_col5" class="data row1 col5" >0.222222</td>
#       <td id="T_74382_row1_col6" class="data row1 col6" >0.133333</td>
#       <td id="T_74382_row1_col7" class="data row1 col7" >0.066667</td>
#       <td id="T_74382_row1_col8" class="data row1 col8" >0.022222</td>
#       <td id="T_74382_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_74382_row1_col10" class="data row1 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_74382_level0_row2" class="row_heading level0 row2" >k = 3</th>
#       <td id="T_74382_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_74382_row2_col1" class="data row2 col1" >0.700000</td>
#       <td id="T_74382_row2_col2" class="data row2 col2" >0.466667</td>
#       <td id="T_74382_row2_col3" class="data row2 col3" >0.291667</td>
#       <td id="T_74382_row2_col4" class="data row2 col4" >0.166667</td>
#       <td id="T_74382_row2_col5" class="data row2 col5" >0.083333</td>
#       <td id="T_74382_row2_col6" class="data row2 col6" >0.033333</td>
#       <td id="T_74382_row2_col7" class="data row2 col7" >0.008333</td>
#       <td id="T_74382_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_74382_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_74382_row2_col10" class="data row2 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_74382_level0_row3" class="row_heading level0 row3" >k = 4</th>
#       <td id="T_74382_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_74382_row3_col1" class="data row3 col1" >0.600000</td>
#       <td id="T_74382_row3_col2" class="data row3 col2" >0.333333</td>
#       <td id="T_74382_row3_col3" class="data row3 col3" >0.166667</td>
#       <td id="T_74382_row3_col4" class="data row3 col4" >0.071429</td>
#       <td id="T_74382_row3_col5" class="data row3 col5" >0.023810</td>
#       <td id="T_74382_row3_col6" class="data row3 col6" >0.004762</td>
#       <td id="T_74382_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_74382_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_74382_r
